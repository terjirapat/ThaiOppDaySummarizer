# %% [markdown]
# https://chatgpt.com/share/687d132f-70f0-8003-8800-16c45376f179

# %% [markdown]
# i extract subtitle from youtube video
# the video is 2hours long
# i want summarize with Key points of the video using llm model
# so i chunk subtitle every 10 minutes and input each chunk to model to summarize
# eg. 1 time summarize for 1 chunk
# and then I combine all the sumarize together
# I use this method because llm model seem to cunfuse when I input the large amount of data into it
# so I chunk it first and do all above
# is it a good method or any method suggest that better than this?

# %% [markdown]
# to do
# - try chunking in token
#     - 1,000–2,000 tokens per chunk is the safe sweet spot
#     - Add 10–20% overlap to catch mid-topic cuts

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.youtube.com/watch?v=ZCoK9nakeJE"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
title = soup.title.string.replace(" - YouTube", "").strip()

# %%
import re

# get video title name
def clean_title(text):
    return re.sub(r'[^0-9a-zA-Z\u0E00-\u0E7F\.]', '', text)
title = clean_title(text=title)

# get video id
match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11}).*", url)
if match:
    video_id = match.group(1)

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Fetch transcript (auto-captions or uploaded)
transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['th', 'en'])

# Optionally, save to file
file_name = f'{title}_{video_id}'
with open(f"{file_name}_subtitle.txt", "w", encoding="utf-8") as f:
    for entry in transcript:
        f.write(f"{entry['start']:.2f}s: {entry['text']}\n")
        # f.write(f"{entry['text']}\n")

# %%
import re

def load_subtitles(file_path):
    subtitles = []
    with open(file_path, encoding='utf-8') as f:
        for line in f:
            match = re.match(r'([0-9.]+)s:\s(.+)', line.strip())
            if match:
                start_time = float(match.group(1))
                text = match.group(2)
                subtitles.append({'start': start_time, 'text': text})
    return subtitles

def chunk_subtitles(subtitles, chunk_size=60, overlap=20):
    """
    Chunk subtitles into segments of `chunk_size` seconds with `overlap` seconds.
    """
    chunks = []
    max_time = subtitles[-1]['start']
    start_time = 0

    while start_time <= max_time:
        end_time = start_time + chunk_size
        chunk_text = []
        for entry in subtitles:
            if start_time <= entry['start'] < end_time:
                chunk_text.append(entry['text'])
        if chunk_text:
            chunks.append({
                'start': start_time,
                'end': end_time,
                'text': ' '.join(chunk_text)
            })
        start_time += chunk_size - overlap
    return chunks

subtitles = load_subtitles(f"{file_name}_subtitle.txt")
chunk_dict = chunk_subtitles(subtitles, chunk_size=600, overlap=60)
# chunk_dict = chunk_subtitles(subtitles, chunk_size=300, overlap=30)

# %%
import re
from pythainlp.tokenize import word_tokenize

def read_text_file(file_path):
    """Read text from a file and return as a string."""
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read()

def remove_timestamps(text):
    """Remove timestamps like '0.12s:' at the start of each line."""
    cleaned_text = re.sub(r'^\s*\d+\.\d+s:\s*', '', text, flags=re.MULTILINE)
    return cleaned_text

def remove_newlines(text):
    """Remove newline characters."""
    return text.replace('\n', '')

def chunk_thai_text(text, max_tokens, overlap):
    """
    Chunk Thai text using PyThaiNLP word tokenizer with overlap.
    """
    words = word_tokenize(text, keep_whitespace=False)
    chunks = []
    start = 0

    while start < len(words):
        end = min(start + max_tokens, len(words))
        chunk = ''.join(words[start:end])  # Join with no spaces for Thai
        chunks.append(chunk)
        start += max_tokens - overlap

    return chunks

# Example usage:
file_path = f"{file_name}_subtitle.txt"
text = read_text_file(file_path)
text = remove_timestamps(text)
text = remove_newlines(text)
chunks = chunk_thai_text(text, max_tokens=1000, overlap=200)

# %%
# # subtitle = [subtitle['text'] for subtitle in subtitles]
# with open(f"{file_name}_subtitle.txt", 'r') as f:
#     contents = f.read()

# %%
title = file_name.split('_')[0]

# %% [markdown]
# ## Use “Key points extraction” instead of general summary
# ## Use hierarchical summarization

# %%
# === PROMPTS ===
KEY_POINTS_PROMPT = """
You are a helpful assistant.
Below is a section of a video transcript.
Extract the key points using clear bullet points.
Label each point with one of these: [Fact], [Idea], [Quote], [Question], [Action].
Be precise. Keep points short and factual.
Do not add commentary or extra text.

Transcript:
\"\"\"
{chunk_text}
\"\"\"
"""

SECTION_MERGE_PROMPT = """
Below are key points extracted from multiple chunks of a section.
Merge them into a single list:
- Remove duplicates or near-duplicates.
- Group similar ideas if needed.
- Keep clear bullet points.
- Preserve labels like [Fact], [Idea], etc.

Key Points:
\"\"\"
{key_points_text}
\"\"\"
"""

FINAL_SUMMARY_PROMPT = """
Below are the section-level key points for the entire video.
Write a single, well-organized summary:
- Merge and deduplicate.
- Organize by themes.
- Keep [Fact], [Idea], [Quote], [Action], etc.
- Present clearly for a slide deck or notes.
- Do not add fluff.

All Section Points:
\"\"\"
{all_sections_text}
\"\"\"
"""

# === HELPERS ===

import ollama
def call_llm(prompt: str):
    response = ollama.chat(
        model="llama3",
        messages=[
            {"role": "system", "content": "You are a precise simplify assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response["message"]["content"]

# %%
# === PIPELINE ===

chunk_key_points = []
print("Extracting key points for each chunk...")
for i, chunk in enumerate(chunks):
    prompt = KEY_POINTS_PROMPT.format(chunk_text=chunk)
    result = call_llm(prompt)
    print(f"Chunk {i+1} done.")
    chunk_key_points.append(result)
    print(result)

# Group into sections, e.g., 3 chunks per section
SECTION_SIZE = 3
section_key_points = []

print("\nMerging chunks into sections...")
for i in range(0, len(chunk_key_points), SECTION_SIZE):
    group = chunk_key_points[i:i+SECTION_SIZE]
    group_text = "\n\n".join(group)
    prompt = SECTION_MERGE_PROMPT.format(key_points_text=group_text)
    result = call_llm(prompt)
    print(f"Section {i//SECTION_SIZE + 1} done.")
    section_key_points.append(result)

# Final merge
print("\nMerging all sections into final summary...")
all_sections_text = "\n\n".join(section_key_points)
final_prompt = FINAL_SUMMARY_PROMPT.format(all_sections_text=all_sections_text)
final_summary = call_llm(final_prompt)

print("\n✅ Final Summary:\n")
print(final_summary)
# Out:
# Extracting key points for each chunk...
# Chunk 1 done.
# Here are the key points from the transcript:
#
# * [Fact]: The company discussed is DNAy Ceramic, also known as DCC.
# * [Idea]: The speaker thinks that the company's value lies in its low price-to-earnings (PE) ratio and dividend yield.
# * [Quote]: "คือในช่องผมนี่ก็จะมีทำเรื่องเกี่ยวกับหุ้นประมาณว่าแบบเป็นหุ้นValueหุ้นที่มีราคาค่อนข้างถูกถ้าเทียบกับPEหรือว่าค่าต่างๆนะครับ"
# * [Action]: The speaker is planning to create a video about the company and its investment opportunities.
# * [Fact]: The company DNAy Ceramic is a Thai ceramic products manufacturer.
# * [Idea]: The speaker thinks that the company's growth potential lies in its ability to expand globally.
# * [Quote]: "เพราะว่าทรงร้านน่ะมันไม่ใช่ร้านแบบแนวขายของแพงขายของพรีเมี่มติดแอร์อะไรประมาณเนี้ยนะครับ"
# * [Action]: The speaker is encouraging viewers to follow the company's progress and consider investing in it.
# * [Fact]: The company DNAy Ceramic has a dividend yield of around 5%.
# * [Idea]: The speaker thinks that the company's value lies in its low price-to-earnings (PE) ratio, which makes it an attractive investment opportunity for those looking for long-term growth.
# * [Quote]: "เป็นหุ้นถูกราคาไม่แพงกำไรสม่ำเสมอจ่ายปันผลสวยงามค่อนข้างโอเคอะไรประมาณเนี้ย"
# * [Action]: The speaker is advising viewers to consider investing in the company's stock, but with caution and a long-term perspective.
# * [Fact]: The company DNAy Ceramic has plans to expand its business globally.
# * [Idea]: The speaker thinks that the company's global expansion potential makes it an attractive investment opportunity for those looking for long-term growth.
# * [Quote]: "เพราะว่าตัวค่าต่างๆอ่ะค่าอัตราต่างๆค่าตัวเลขต่างๆเนี่ยมันเข้าเค้าหมดเลยครับ"
# * [Action]: The speaker is encouraging viewers to do their own research and due diligence before investing in the company's stock.
# Chunk 2 done.
# Here are the key points extracted from the transcript:
#
# * [Fact]: The speaker thinks that Global is a good investment opportunity, with expansion plans and strong brand recognition.
# * [Idea]: The speaker believes that DNAy's stock price will stabilize once it has expanded its business in Thailand.
# * [Quote]: "If you want to get into the game, I think HomeProGlobal is a better option because the company is big and has a clear direction."
# * [Question]: None
# * [Action]: The speaker advises investors to use their own judgment and do their research before making investment decisions.
#
# Additionally, here are some key points related to DNAy's business:
#
# * [Fact]: DNAy has been expanding its business in Thailand and has a strong brand recognition.
# * [Idea]: The speaker believes that DNAy will continue to grow its business in Thailand and potentially expand into other countries.
# * [Quote]: None
# * [Question]: None
# * [Action]: None
#
# Some key points related to the stock market:
#
# * [Fact]: The speaker thinks that DNAy's stock price has been affected by its expansion plans and potential competition from other companies.
# * [Idea]: The speaker believes that the company's stock price will stabilize once it has expanded its business in Thailand.
# * [Quote]: None
# * [Question]: None
# * [Action]: None
# Chunk 3 done.
# Here are the key points extracted from the transcript in clear bullet points, labeled with one of the following: [Fact], [Idea], [Quote], [Question], or [Action]:
#
# * [Fact]: The company's revenue is mainly from domestic sales (96%) rather than exports (4%).
# * [Fact]: The company's revenue has decreased over time, but started to recover in Q1 2025.
# * [Fact]: The average price of the company's products has increased due to a focus on high-end products.
# * [Idea]: The company is trying to diversify its product range and customer base.
# * [Quote]: "If we don't do something, we'll lose in the long run." - Unknown speaker
# * [Action]: The company needs to review and adjust its business strategy to stay competitive.
# * [Question]: What will be the impact of the company's focus on high-end products on its revenue and profitability?
# * [Fact]: The majority of the company's customers are located in the northern and northeastern regions (70%).
# * [Idea]: The company may need to adjust its business strategy to cater to different customer segments.
# * [Quote]: "It's not just about making money, it's about creating value." - Unknown speaker
# * [Action]: The company needs to monitor its cash flow and liquidity levels to ensure it can meet its financial obligations.
# * [Question]: How will the company's revenue and profitability be affected by changes in the market and industry trends?
# * [Fact]: The company has a strong track record of paying dividends, with a potential dividend yield of 80%.
# * [Idea]: The company may need to adjust its dividend policy to reflect changes in its financial performance.
# * [Quote]: "The key is to find the right balance between short-term and long-term goals." - Unknown speaker
# Chunk 4 done.
# Here are the key points from the transcript, labeled as [Fact], [Idea], [Quote], [Question], or [Action]:
#
# * [Fact]: The company's main products are mass medium and medium-to-high-end products, with 70% of revenue coming from mass medium. (around 1:30)
# * [Fact]: The company has a significant presence in the northern and northeastern regions, with 35% of revenue coming from these areas. (around 2:10)
# * [Idea]: The CEO may be trying to increase the proportion of high-end products in their portfolio. (around 2:20)
# * [Quote]: "We're not following the same old path... We want to make it bigger and better." (around 3:00)
# * [Fact]: The company's EBITDA and profit for the period have been increasing, with a slight dip in Q1. (around 4:10)
# * [Fact]: The dividend payout ratio has increased from 53% to 95%, indicating a high level of payout. (around 5:00)
# * [Idea]: The company may be trying to maintain a high level of payouts to shareholders, potentially to support the stock price. (around 5:10)
# * [Fact]: The company's financials show an increase in net debt from around 80% to 50%, indicating a decrease in leverage. (around 6:00)
# * [Fact]: The ROE and ROA have improved, indicating a higher return on equity and assets. (around 7:10)
# * [Question]: Why is the company's balance sheet showing a high level of debt compared to other companies in the same industry? (around 8:20)
# * [Action]: The speaker suggests that investors should look at the company's financials and management's track record before making an investment decision.
# Chunk 5 done.
# Here are the key points extracted from the transcript using clear bullet points:
#
# [Fact]
# • ROE and ROA decreased over time
# • DCC's debt-to-equity ratio is low
# • The company's assets have been growing at a rate of 10,000 baht per year for the past three years
#
# [Idea]
# • The company's financial performance has been improving, but may not be as strong as it was in the past
# • The company's return on equity (ROE) and return on asset (ROA) are similar, suggesting that the company is not highly leveraged
# • The company's balance sheet is largely debt-free, which could indicate a low level of risk
#
# [Quote]
# • "ROE มันมาจาก returnonequity แต่ว่า ROA มันมาจาก returnonasset อ่ะ" (ROE comes from return on equity, while ROA comes from return on asset)
# • "ถ้าเกิด ROA กับ ROE มันต่างกันมาก เนี่ยแปลว่ามันค่อนข้างเยอะ เพราะว่า equity เนี่ยมันเพราะว่า asset เนี่ยมันมาจาก equity คูณตัวหนี้สิน บวกกับตัวหนี้สิน นะครับ" (If ROA and ROE are significantly different, it means that the company's equity is being used to finance its assets, which could indicate a high level of risk)
#
# [Question]
# • What will happen to DCC's financial performance in the future?
#
# [Action]
# • The company has been trying to improve its financial performance by increasing its revenue and reducing its expenses
# • The company has also been trying to reduce its debt-to-equity ratio
#
# Note: These points are based on my understanding of the transcript, and may not be exactly what was intended.
# Chunk 6 done.
# Here are the key points extracted from the transcript using clear bullet points:
#
# **[Fact]**
#
# * DCC's value is decreasing due to declining profits and growth issues.
# * The company's dividend payout ratio has changed, leading to uncertainty among investors.
#
# **[Idea]**
#
# * Investing in DCC may be overvalued based on its declining growth rate.
# * Valuation methods such as DCF, DDM, or relative PE ratios should be used to assess the stock's value.
# * The author suggests that the stock is not overvalued and that investors should consider the company's long-term potential.
#
# **[Quote]**
#
# * "It's like a game of guessing the price, and I'm saying it's overvalued."
# * "We have to be careful with our investment decisions."
#
# **[Action]**
#
# * The author suggests using InvestingPro, a stock analysis tool, to evaluate DCC's value.
# * He also promotes his own course on stock market investing.
#
# Note: Some points may not fit neatly into these categories, but I've tried to label them as accurately as possible based on the context.
# Chunk 7 done.
# Here are the key points extracted from the transcript:
#
# * [Idea] If you're interested in using this app, it's comprehensive and easy to use. You don't need to set up Excel yourself.
# * [Action] Click on the link below to get a coupon automatically.
# * [Idea] The second thing is that I did a course with Skillern. It's a 10-year experience in the financial market. If you want to avoid losing money or making mistakes, this course can help.
# * [Fact] DCC (Distributed Capital Company) is one of the options to consider when investing in stocks.
# * [Idea] HomeProGlobal is another brand that is known for its strong branding and marketing.
# * [Question] Do you know what happens in other provinces? How do they market their products?
# * [Action] Please share your thoughts or experiences in the comments below.
# * [Idea] This course is suitable for anyone who wants to learn about investing in stocks, including those with little experience.
# * [Fact] I have 10 years of experience in the financial market and I'm the owner of this YouTube channel and Facebook page.
# * [Action] The course name is "10 lessons to avoid losing money" and it summarizes the mistakes that we often make when investing in stocks.
# Chunk 8 done.
# Here are the key points extracted from the transcript:
#
# • [Fact]: The speaker will summarize a lesson that can lead to financial ruin.
# • [Idea]: The speaker believes the lesson is useful for all investors, both new and experienced.
# • [Quote]: "มันมาจากการศึกษาทุกอย่างแล้วก็ประสบการณ์ของผมนะครับ" (The lesson comes from my education and experience in the market over the past 10 years.)
# • [Fact]: The speaker has gained valuable experience in the market over the past 10 years.
# • [Idea]: The speaker thinks the lesson is worth more than its price, considering the potential loss of investment.
# • [Action]: The speaker encourages everyone to try out the course and see for themselves.
# • [Fact]: The course is online, allowing students to learn at any time and place.
#
# Merging chunks into sections...
# Section 1 done.
# Section 2 done.
# Section 3 done.
#
# Merging all sections into final summary...
#
# ✅ Final Summary:
#
# Here is a well-organized summary of the section-level key points:
#
# **DNAy Ceramic (DCC) Key Points**
#
# * **[Fact]**:
# 	+ DCC is a Thai ceramic products manufacturer with a dividend yield of around 5%.
# 	+ The company has plans to expand its business globally.
# 	+ Company's main products are mass medium and medium-to-high-end products, with 70% of revenue coming from mass medium.
# 	+ Company has a significant presence in the northern and northeastern regions, with 35% of revenue coming from these areas.
# 	+ EBITDA and profit for the period have been increasing, with a slight dip in Q1.
# 	+ Dividend payout ratio has increased from 53% to 95%, indicating a high level of payout.
# 	+ Company's financials show an increase in net debt from around 80% to 50%, indicating a decrease in leverage.
# 	+ ROE and ROA have improved, indicating a higher return on equity and assets.
# * **[Idea]**:
# 	+ The company's value lies in its low price-to-earnings (PE) ratio and dividend yield, making it an attractive investment opportunity for those looking for long-term growth.
# 	+ The CEO may be trying to increase the proportion of high-end products in their portfolio.
# 	+ The company may be trying to maintain a high level of payouts to shareholders, potentially to support the stock price.
# * **[Quote]**:
# 	+ "We're not following the same old path... We want to make it bigger and better."
# 	+ "ROE มันมาจาก returnonequity แต่ว่า ROA มันมาจาก returnonasset อ่ะ" (ROE comes from return on equity, while ROA comes from return on asset)
# 	+ "ถ้าเกิด ROA กับ ROE มันต่างกันมาก เนี่ยแปลว่ามันค่อนข้างเยอะ เพราะว่า equity เนี่ยมันเพราะว่า asset เนี่ยมันมาจาก equity คูณตัวหนี้สิน บวกกับต้าหนี้สิน นะครับ" (If ROA and ROE are significantly different, it means that the company's equity is being used to finance its assets, which could indicate a high level of risk)
# * **[Action]**:
# 	+ The speaker suggests that investors should look at the company's financials and management's track record before making an investment decision.
# 	+ The author suggests using InvestingPro, a stock analysis tool, to evaluate DCC's value.
#
# Note: I removed duplicates and near-duplicates, grouped similar ideas together, and preserved labels like [Fact], [Idea], etc.

# %%
with open(f"{file_name}_summary_v3.txt", "w", encoding="utf-8") as f:
    f.write(final_summary)

# %% [markdown]
# ## Try Map-Reduce with embeddings (advanced)
